# %%
#H2

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE, AdaptVQE
from qiskit_algorithms.optimizers import COBYLA,L_BFGS_B
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "sto-3g"
BOND_LENGTH = 0.7414  # Angstrom

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of H2 using four different methods:
    UHF, FCI, standard VQE, and AdaptVQE.
    """
    print(f"H₂ Ground State Calculation Comparison for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's geometry as a string
    atom_str = f"H 0 0 0; H 0 0 {BOND_LENGTH}"

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    mol = gto.M(atom=atom_str, basis=BASIS_SET, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    # Note: For H2, RHF is sufficient as a starting point for FCI
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculations (VQE and AdaptVQE) ---
    
    # Set up the chemical problem for Qiskit
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET)
    problem = driver.run()
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz, which is used by both VQE methods
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )
    optimizer = L_BFGS_B(maxiter=1000)
    

    # Define the VQE instance that both algorithms will use
    vqe_instance = VQE(Estimator(), ansatz, optimizer)
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    results['VQE'] = result_vqe.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")
    
    # --- AdaptVQE Calculation ---
    print("--- Running AdaptVQE Calculation ---")
    start_time = time.time()
    adapt_vqe = AdaptVQE(vqe_instance)
    # This temporary fix is needed for compatibility in some Qiskit versions
    adapt_vqe.supports_aux_operators = lambda: True
    
    solver_adapt = GroundStateEigensolver(mapper, adapt_vqe)
    result_adapt = solver_adapt.solve(problem)
    results['AdaptVQE'] = result_adapt.total_energies[0]
    print(f"AdaptVQE Energy: {results['AdaptVQE']:.8f} Hartree")
    print(f"AdaptVQE finished in {time.time() - start_time:.2f}s\n")

    # --- Final Summary ---
    print("\n" + "="*50)
    print("          Final Energy Summary")
    print("="*50)
    print(f"  UHF Energy:         {results['UHF']} Hartree")
    print(f"  Standard VQE Energy:  {results['VQE']} Hartree")
    print(f"  AdaptVQE Energy:      {results['AdaptVQE']:.8} Hartree")
    print(f"  FCI (Exact) Energy:   {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum results to the exact FCI energy
    print(f"  Error (VQE vs FCI):   {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print(f"  Error (AdaptVQE vs FCI): {abs(results['AdaptVQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# H₂ Ground State Calculation Comparison for Basis: sto-3g
# Started at: 2025-09-17 12:47:19
#
# --- Running Classical Calculations ---
# UHF Energy: -1.11668439 Hartree
# FCI (Exact) Energy: -1.13727017 Hartree
# Classical calculations finished in 0.44s
#
# --- Running Standard VQE Calculation ---
# /tmp/ipykernel_492559/208599009.py:77: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_instance = VQE(Estimator(), ansatz, optimizer)
# Standard VQE Energy: -1.13727017 Hartree
# VQE finished in 0.81s
#
# --- Running AdaptVQE Calculation ---
# AdaptVQE Energy: -1.13727017 Hartree
# AdaptVQE finished in 0.43s
#
#
# ==================================================
#           Final Energy Summary
# ==================================================
#   UHF Energy:         -1.1166843870853413 Hartree
#   Standard VQE Energy:  -1.1372701746608649 Hartree
#   AdaptVQE Energy:      -1.1372702 Hartree
#   FCI (Exact) Energy:   -1.13727017 Hartree
# --------------------------------------------------
#   Error (VQE vs FCI):   0.00000000 Hartree
#   Error (AdaptVQE vs FCI): 0.00000000 Hartree
# ==================================================

# %%
"""RESULTS
H₂ Ground State Calculation Comparison for Basis: sto-3g
Started at: 2025-09-09 12:10:39

--- Running Classical Calculations ---
UHF Energy: -1.11668439 Hartree
FCI (Exact) Energy: -1.13727017 Hartree
Classical calculations finished in 0.29s

--- Running Standard VQE Calculation ---
/tmp/ipykernel_959151/1457183300.py:77: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_instance = VQE(Estimator(), ansatz, optimizer)
Standard VQE Energy: -1.13727017 Hartree
VQE finished in 1.95s

--- Running AdaptVQE Calculation ---
AdaptVQE Energy: -1.13727017 Hartree
AdaptVQE finished in 0.97s


==================================================
          Final Energy Summary
==================================================
  UHF Energy:         -1.11668439 Hartree
  Standard VQE Energy:  -1.13727017 Hartree
  AdaptVQE Energy:      -1.13727017 Hartree
  FCI (Exact) Energy:   -1.13727017 Hartree
--------------------------------------------------
  Error (VQE vs FCI):   0.00000000 Hartree
  Error (AdaptVQE vs FCI): 0.00000000 Hartree
=================================================="""

# %%
#H3+

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE, AdaptVQE
from qiskit_algorithms.optimizers import SLSQP,L_BFGS_B
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "3-21g"
BOND_LENGTH = 0.8561
  # Angstrom, standard bond length for H3+

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of H3+ using four different methods:
    UHF, FCI, standard VQE, and AdaptVQE.
    """
    print(f"H₃⁺ Ground State Calculation Comparison for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's geometry as an equilateral triangle
    r = BOND_LENGTH / np.sqrt(3)
    atom_str = (
        f"H {r:.4f} 0.0 0.0; "
        f"H {-r/2:.4f} {r * np.sqrt(3)/2:.4f} 0.0; "
        f"H {-r/2:.4f} {-r * np.sqrt(3)/2:.4f} 0.0"
    )

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    # Note: charge=1 for the H3+ cation
    mol = gto.M(atom=atom_str, basis=BASIS_SET, charge=1, spin=0, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculations (VQE and AdaptVQE) ---
    
    # Set up the chemical problem for Qiskit, specifying charge=1
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET, charge=1, spin=0)
    problem = driver.run()
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz, which is used by both VQE methods
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )

    # Define the VQE instance that both algorithms will use
    vqe_instance = VQE(Estimator(), ansatz, L_BFGS_B())
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    results['VQE'] = result_vqe.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")
    
    # --- AdaptVQE Calculation ---
    print("--- Running AdaptVQE Calculation ---")
    start_time = time.time()
    adapt_vqe = AdaptVQE(vqe_instance)
    # This temporary fix is needed for compatibility in some Qiskit versions
    adapt_vqe.supports_aux_operators = lambda: True
    
    solver_adapt = GroundStateEigensolver(mapper, adapt_vqe)
    result_adapt = solver_adapt.solve(problem)
    results['AdaptVQE'] = result_adapt.total_energies[0]
    print(f"AdaptVQE Energy: {results['AdaptVQE']:.8f} Hartree")
    print(f"AdaptVQE finished in {time.time() - start_time:.2f}s\n")

    # --- Final Summary ---
    print("\n" + "="*50)
    print("          Final Energy Summary")
    print("="*50)
    print(f"  UHF Energy:         {results['UHF']:.8f} Hartree")
    print(f"  Standard VQE Energy:  {results['VQE']:.8f} Hartree")
    print(f"  AdaptVQE Energy:      {results['AdaptVQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy:   {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum results to the exact FCI energy
    print(f"  Error (VQE vs FCI):   {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print(f"  Error (AdaptVQE vs FCI): {abs(results['AdaptVQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# H₃⁺ Ground State Calculation Comparison for Basis: 3-21g
# Started at: 2025-09-16 16:00:50
#
# --- Running Classical Calculations ---
# UHF Energy: -1.26997919 Hartree
# FCI (Exact) Energy: -1.29989474 Hartree
# Classical calculations finished in 0.52s
# /tmp/ipykernel_399573/549558148.py:81: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_instance = VQE(Estimator(), ansatz, L_BFGS_B())
# --- Running Standard VQE Calculation ---
# Standard VQE Energy: -1.29989474 Hartree
# VQE finished in 242.43s
#
# --- Running AdaptVQE Calculation ---
# AdaptVQE Energy: -1.29989474 Hartree
# AdaptVQE finished in 377.88s
#
#
# ==================================================
#           Final Energy Summary
# ==================================================
#   UHF Energy:         -1.26997919 Hartree
#   Standard VQE Energy:  -1.29989474 Hartree
#   AdaptVQE Energy:      -1.29989474 Hartree
#   FCI (Exact) Energy:   -1.29989474 Hartree
# --------------------------------------------------
#   Error (VQE vs FCI):   0.00000000 Hartree
#   Error (AdaptVQE vs FCI): 0.00000000 Hartree
# ==================================================

# %%
"""H₃⁺ Ground State Calculation Comparison for Basis: 3-21g
Started at: 2025-09-09 12:13:15

--- Running Classical Calculations ---
UHF Energy: -1.26997919 Hartree
FCI (Exact) Energy: -1.29989474 Hartree
Classical calculations finished in 0.54s

/tmp/ipykernel_959151/2862908298.py:81: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_instance = VQE(Estimator(), ansatz, SLSQP())
--- Running Standard VQE Calculation ---
Standard VQE Energy: -1.29989455 Hartree
VQE finished in 153.49s

--- Running AdaptVQE Calculation ---
AdaptVQE Energy: -1.29989462 Hartree
AdaptVQE finished in 323.24s


==================================================
          Final Energy Summary
==================================================
  UHF Energy:         -1.26997919 Hartree
  Standard VQE Energy:  -1.29989455 Hartree
  AdaptVQE Energy:      -1.29989462 Hartree
  FCI (Exact) Energy:   -1.29989474 Hartree
--------------------------------------------------
  Error (VQE vs FCI):   0.00000019 Hartree
  Error (AdaptVQE vs FCI): 0.00000012 Hartree
==================================================

==================================================
           Final Energy Summary for H₃⁺
==================================================
  UHF Energy:          -1.23685874 Hartree
  Standard VQE Energy: -1.26126402 Hartree
  FCI (Exact) Energy:  -1.26126402 Hartree
--------------------------------------------------
  Error (VQE vs FCI):  0.00000000 Hartree
==================================================

"""

# %%
"""OH-"""

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE, AdaptVQE
from qiskit_algorithms.optimizers import SLSQP,COBYLA,L_BFGS_B
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "sto-3g"
BOND_LENGTH =  0.9640  # Angstrom, equilibrium bond length for OH-

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of OH- using four different methods:
    UHF, FCI, standard VQE, and AdaptVQE.
    """
    print(f"OH⁻ Ground State Calculation Comparison for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's geometry as a string
    atom_str = f"O 0 0 0; H 0 0 {BOND_LENGTH}"

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    # Note: charge=-1 and spin=0 for the hydroxide anion
    mol = gto.M(atom=atom_str, basis=BASIS_SET, charge=-1, spin=0, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculations (VQE and AdaptVQE) ---
    
    # Set up the chemical problem for Qiskit, specifying charge=-1
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET, charge=-1, spin=0)
    problem = driver.run()
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz, which is used by both VQE methods
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )

    # Define the VQE instance that both algorithms will use
    vqe_instance = VQE(Estimator(), ansatz, L_BFGS_B(maxiter=1500))
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    results['VQE'] = result_vqe.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")
    
    # --- AdaptVQE Calculation ---
    print("--- Running AdaptVQE Calculation ---")
    start_time = time.time()
    adapt_vqe = AdaptVQE(vqe_instance)
    # This temporary fix is needed for compatibility in some Qiskit versions
    adapt_vqe.supports_aux_operators = lambda: True
    
    solver_adapt = GroundStateEigensolver(mapper, adapt_vqe)
    result_adapt = solver_adapt.solve(problem)
    results['AdaptVQE'] = result_adapt.total_energies[0]
    print(f"AdaptVQE Energy: {results['AdaptVQE']:.8f} Hartree")
    print(f"AdaptVQE finished in {time.time() - start_time:.2f}s\n")

    # --- Final Summary ---
    print("\n" + "="*50)
    print("          Final Energy Summary")
    print("="*50)
    print(f"  UHF Energy:         {results['UHF']:.8f} Hartree")
    print(f"  Standard VQE Energy:  {results['VQE']:.8f} Hartree")
    print(f"  AdaptVQE Energy:      {results['AdaptVQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy:   {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum results to the exact FCI energy
    print(f"  Error (VQE vs FCI):   {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print(f"  Error (AdaptVQE vs FCI): {abs(results['AdaptVQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# OH⁻ Ground State Calculation Comparison for Basis: sto-3g
# Started at: 2025-09-17 10:25:10
#
# --- Running Classical Calculations ---
# UHF Energy: -74.05632813 Hartree
# FCI (Exact) Energy: -74.08035479 Hartree
# Classical calculations finished in 0.46s
#
# --- Running Standard VQE Calculation ---
# /tmp/ipykernel_456010/912677371.py:75: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_instance = VQE(Estimator(), ansatz, L_BFGS_B(maxiter=1500))
# Standard VQE Energy: -74.08035479 Hartree
# VQE finished in 1067.63s
#
# --- Running AdaptVQE Calculation ---
# AdaptVQE Energy: -74.08032158 Hartree
# AdaptVQE finished in 543.30s
#
#
# ==================================================
#           Final Energy Summary
# ==================================================
#   UHF Energy:         -74.05632813 Hartree
#   Standard VQE Energy:  -74.08035479 Hartree
#   AdaptVQE Energy:      -74.08032158 Hartree
#   FCI (Exact) Energy:   -74.08035479 Hartree
# --------------------------------------------------
#   Error (VQE vs FCI):   0.00000000 Hartree
#   Error (AdaptVQE vs FCI): 0.00003322 Hartree
# ==================================================

# %%
"""OH⁻ Ground State Calculation Comparison for Basis: sto-3g
Started at: 2025-09-09 12:36:29

--- Running Classical Calculations ---
UHF Energy: -74.06501711 Hartree
FCI (Exact) Energy: -74.09428808 Hartree
Classical calculations finished in 0.60s

/tmp/ipykernel_1000811/3289249938.py:75: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_instance = VQE(Estimator(), ansatz, SLSQP())
--- Running Standard VQE Calculation ---
Standard VQE Energy: -74.09428756 Hartree
VQE finished in 197.96s

--- Running AdaptVQE Calculation ---
AdaptVQE Energy: -74.09424738 Hartree
AdaptVQE finished in 244.18s


==================================================
          Final Energy Summary
==================================================
  UHF Energy:         -74.06501711 Hartree
  Standard VQE Energy:  -74.09428756 Hartree
  AdaptVQE Energy:      -74.09424738 Hartree
  FCI (Exact) Energy:   -74.09428808 Hartree
--------------------------------------------------
  Error (VQE vs FCI):   0.00000052 Hartree
  Error (AdaptVQE vs FCI): 0.00004070 Hartree
=================================================="""

  OH- Ground State Calculation Comparison for Basis: sto-3g
Started at: 2025-09-10 13:47:37

--- Running Classical Calculations ---
UHF Energy: -74.05739919 Hartree
FCI (Exact) Energy: -74.08172336 Hartree
Classical calculations finished in 0.59s

--- Running UCCSD VQE Calculation ---
/tmp/ipykernel_1328555/3984640952.py:81: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_uccsd = VQE(Estimator(), uccsd_ansatz, optimizer)
UCCSD VQE Energy: -74.08172083 Hartree
UCCSD VQE finished in 158.07s

--- Running 2-UpCCGSD VQE Calculation ---
/tmp/ipykernel_1328555/3984640952.py:111: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_kupccgsd = VQE(Estimator(), kupccgsd_ansatz, kupccgsd_optimizer)

# %%
"""LiH"""

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE, AdaptVQE
from qiskit_algorithms.optimizers import SLSQP, L_BFGS_B
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "sto-3g"
BOND_LENGTH = 1.5949  # Angstrom, experimental equilibrium bond length for LiH

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of LiH using four different methods:
    UHF, FCI, standard VQE, and AdaptVQE.
    """
    print(f"LiH Ground State Calculation Comparison for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's geometry as a string
    atom_str = f"Li 0 0 0; H 0 0 {BOND_LENGTH}"

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    # Note: charge=0 and spin=0 for the neutral LiH molecule
    mol = gto.M(atom=atom_str, basis=BASIS_SET, charge=0, spin=0, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculations (VQE and AdaptVQE) ---
    
    # Set up the chemical problem for Qiskit, specifying charge=0
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET, charge=0, spin=0)
    problem = driver.run()
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz, which is used by both VQE methods
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )

    # Define the VQE instance that both algorithms will use
    vqe_instance = VQE(Estimator(), ansatz, L_BFGS_B())
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    results['VQE'] = result_vqe.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")
    
    # --- AdaptVQE Calculation ---
    print("--- Running AdaptVQE Calculation ---")
    start_time = time.time()
    adapt_vqe = AdaptVQE(vqe_instance)
    # This temporary fix is needed for compatibility in some Qiskit versions
    adapt_vqe.supports_aux_operators = lambda: True
    
    solver_adapt = GroundStateEigensolver(mapper, adapt_vqe)
    result_adapt = solver_adapt.solve(problem)
    results['AdaptVQE'] = result_adapt.total_energies[0]
    print(f"AdaptVQE Energy: {results['AdaptVQE']:.8f} Hartree")
    print(f"AdaptVQE finished in {time.time() - start_time:.2f}s\n")

    # --- Final Summary ---
    print("\n" + "="*50)
    print("          Final Energy Summary")
    print("="*50)
    print(f"  UHF Energy:         {results['UHF']:.8f} Hartree")
    print(f"  Standard VQE Energy:  {results['VQE']:.8f} Hartree")
    print(f"  AdaptVQE Energy:      {results['AdaptVQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy:   {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum results to the exact FCI energy
    print(f"  Error (VQE vs FCI):   {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print(f"  Error (AdaptVQE vs FCI): {abs(results['AdaptVQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()

# %%
"""LiH Ground State Calculation Comparison for Basis: sto-3g
Started at: 2025-09-09 12:28:58

--- Running Classical Calculations ---
UHF Energy: -7.86202696 Hartree
FCI (Exact) Energy: -7.88240341 Hartree
Classical calculations finished in 0.62s

/tmp/ipykernel_999850/1448371883.py:75: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_instance = VQE(Estimator(), ansatz, SLSQP())
--- Running Standard VQE Calculation ---
Standard VQE Energy: -7.88239258 Hartree
VQE finished in 1835.60s

--- Running AdaptVQE Calculation ---
AdaptVQE Energy: -7.88194501 Hartree
AdaptVQE finished in 2442.26s


==================================================
          Final Energy Summary
==================================================
  UHF Energy:         -7.86202696 Hartree
  Standard VQE Energy:  -7.88239258 Hartree
  AdaptVQE Energy:      -7.88194501 Hartree
  FCI (Exact) Energy:   -7.88240341 Hartree
--------------------------------------------------
  Error (VQE vs FCI):   0.00001083 Hartree
  Error (AdaptVQE vs FCI): 0.00045840 Hartree
=================================================="""
LiH Ground State Calculation Comparison for Basis: sto-3g
Started at: 2025-09-10 13:35:41

--- Running Classical Calculations ---
UHF Energy: -7.86202696 Hartree
FCI (Exact) Energy: -7.88240341 Hartree
Classical calculations finished in 2.32s

--- Running UCCSD VQE Calculation ---
/tmp/ipykernel_1345152/349821736.py:81: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_uccsd = VQE(Estimator(), uccsd_ansatz, optimizer)
UCCSD VQE Energy: -7.88239258 Hartree
UCCSD VQE finished in 1706.90s

--- Running 2-UpCCGSD VQE Calculation ---
LiH Ground State Calculation Comparison for Basis: sto-3g
Started at: 2025-09-10 13:35:41

--- Running Classical Calculations ---
UHF Energy: -7.86202696 Hartree
FCI (Exact) Energy: -7.88240341 Hartree
Classical calculations finished in 2.32s

--- Running UCCSD VQE Calculation ---
/tmp/ipykernel_1345152/349821736.py:81: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
  vqe_uccsd = VQE(Estimator(), uccsd_ansatz, optimizer)

# %%
Calculating VQE energy for LiH at bond length 1.5949 Å using sto3g basis set...
VQE energy at standard bond length: -7.882175879993409 Hartree

Calculating LiH energy at bond length 1.5949 Å with basis sto-3g
VQE energy: -7.882175880011617 Hartree
Exact (FCI) energy: -7.882175990801266 Hartree
Energy difference: 1.1078964945454572e-07 mHartree

Trying with a larger basis set...
Calculating LiH energy at bond length 1.5949 Å with basis 6-31g

# %%
import numpy as np
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit.algorithms.minimum_eigensolvers import NumPyMinimumEigensolver, VQE
from qiskit.algorithms.optimizers import SLSQP
from qiskit_aer.primitives import Estimator

# Set to use Hamiltonian representation that's better for exact eigensolver
import qiskit_nature
qiskit_nature.settings.use_pauli_sum_op = False

def calculate_lih_energy(bond_length=1.5949, basis="sto-3g"):
    """
    Calculate VQE and exact (FCI) energies for LiH at a specific bond length
    
    Args:
        bond_length (float): Interatomic distance in Angstroms
        basis (str): Basis set name
        
    Returns:
        tuple: (VQE energy, exact energy)
    """
    print(f"Calculating LiH energy at bond length {bond_length} Å with basis {basis}")
    
    # Define molecule
    molecule = MoleculeInfo(
        symbols=["Li", "H"],
        coords=([0.0, 0.0, 0.0], [bond_length, 0.0, 0.0]),
        multiplicity=1,
        charge=0,
    )
    
    # Create driver with specified basis set
    driver = PySCFDriver.from_molecule(
        molecule,
        basis=basis,
    )
    
    # Run electronic structure calculation
    properties = driver.run()
    
    # Transform the problem (freeze core orbitals)
    problem = FreezeCoreTransformer(
        freeze_core=True, remove_orbitals=[-3, -2]
    ).transform(properties)
    
    # Extract problem parameters
    num_particles = problem.num_particles
    num_spatial_orbitals = problem.num_spatial_orbitals
    
    # Map to qubit operator
    mapper = ParityMapper(num_particles=num_particles)
    qubit_op = mapper.map(problem.second_q_ops()[0])
    
    # Calculate exact energy
    numpy_solver = NumPyMinimumEigensolver()
    exact_result = numpy_solver.compute_minimum_eigenvalue(qubit_op)
    exact_energy = problem.interpret(exact_result).total_energies[0].real
    
    # Calculate VQE energy
    init_state = HartreeFock(num_spatial_orbitals, num_particles, mapper)
    var_form = UCCSD(
        num_spatial_orbitals, num_particles, mapper, initial_state=init_state
    )
    optimizer = SLSQP(maxiter=100)
    estimator = Estimator(approximation=True)
    
    vqe = VQE(
        estimator,
        var_form,
        optimizer,
        initial_point=[0] * var_form.num_parameters,
    )
    
    vqe_calc = vqe.compute_minimum_eigenvalue(qubit_op)
    vqe_energy = problem.interpret(vqe_calc).total_energies[0].real
    
    print(f"VQE energy: {vqe_energy:.8f} Hartree")
    print(f"Exact (FCI) energy: {exact_energy:.8f} Hartree")
    print(f"Energy difference: {(vqe_energy - exact_energy) * 1000:.8f} mHartree")
    
    # Return reference to problem for additional analysis if needed
    return vqe_energy, exact_energy, problem

# Calculate energy at standard LiH bond length with different basis sets
standard_length = 1.5949  # Standard LiH bond length in Angstroms

# Minimal basis
vqe_energy_sto3g, exact_energy_sto3g, _ = calculate_lih_energy(standard_length, "sto-3g")
# Out:
# Calculating LiH energy at bond length 1.5949 Å with basis sto-3g
# VQE energy: -7.88217588 Hartree
# Exact (FCI) energy: -7.88217599 Hartree
# Energy difference: 0.00011078 mHartree

# %%
"H2O"

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "sto-3g"

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of H2O using three different methods:
    UHF, FCI, and standard VQE.
    """
    print(f"💧 H₂O Ground State Calculation Comparison for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's geometry as a string (standard geometry)
    atom_str = "O 0.000000 0.000000 0.117790; H 0.000000 0.755453 -0.471161; H 0.000000 -0.755453 -0.471161"

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    mol = gto.M(atom=atom_str, basis=BASIS_SET, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    # RHF is a suitable starting point for the FCI calculation
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculation (VQE) ---
    
    # Set up the chemical problem for Qiskit
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET)
    problem = driver.run()
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )
    
    # Set the optimizer to L-BFGS-B
    optimizer = L_BFGS_B()

    # Define the VQE instance
    vqe_instance = VQE(Estimator(), ansatz, optimizer)
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation (Optimizer: L-BFGS-B) ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    results['VQE'] = result_vqe.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")
    
    # --- Final Summary ---
    print("\n" + "="*50)
    print("           Final Energy Summary for H₂O")
    print("="*50)
    print(f"  UHF Energy:          {results['UHF']:.8f} Hartree")
    print(f"  Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy:  {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum result to the exact FCI energy
    print(f"  Error (VQE vs FCI):  {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# 💧 H₂O Ground State Calculation Comparison for Basis: sto-3g
# Started at: 2025-09-16 12:26:35
#
# --- Running Classical Calculations ---
# UHF Energy: -74.96314678 Hartree
# FCI (Exact) Energy: -75.01277618 Hartree
# Classical calculations finished in 0.52s
# /tmp/ipykernel_352371/1080916399.py:77: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_instance = VQE(Estimator(), ansatz, optimizer)
# --- Running Standard VQE Calculation (Optimizer: L-BFGS-B) ---

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.transformers import FreezeCoreTransformer


# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE, AdaptVQE
from qiskit_algorithms.optimizers import SLSQP
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "sto-3g" # Using a minimal basis set for faster computation
BOND_LENGTH = 1.087  # Angstrom, standard C-H bond length for Methane

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of CH4 using four different methods:
    UHF, FCI, standard VQE, and AdaptVQE.
    """
    print(f"CH₄ Ground State Calculation Comparison for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's tetrahedral geometry
    # Coordinates are derived from the C-H bond length
    val = BOND_LENGTH / np.sqrt(3)
    atom_str = (
        f"C 0.0000 0.0000 0.0000; "
        f"H {val:.4f} {val:.4f} {val:.4f}; "
        f"H {val:.4f} {-val:.4f} {-val:.4f}; "
        f"H {-val:.4f} {val:.4f} {-val:.4f}; "
        f"H {-val:.4f} {-val:.4f} {val:.4f}"
    )

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    # Note: charge=0 for the neutral CH4 molecule
    mol = gto.M(atom=atom_str, basis=BASIS_SET, charge=0, spin=0, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculations (VQE and AdaptVQE) ---
    
    # Set up the chemical problem for Qiskit, specifying charge=0
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET, charge=0, spin=0)
    problem_full = driver.run()
    
    # Freeze the 1s core orbital of the Carbon atom to reduce problem size
    transformer = FreezeCoreTransformer(freeze_core=True)
    problem = transformer.transform(problem_full)
    
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz, which is used by both VQE methods
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )

    # Define the VQE instance that both algorithms will use
    vqe_instance = VQE(Estimator(), ansatz, SLSQP())
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    # Use problem.interpret to get the final energy including frozen core contributions
    final_vqe_result = problem.interpret(result_vqe)
    results['VQE'] = final_vqe_result.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")
    
    # --- AdaptVQE Calculation ---
    print("--- Running AdaptVQE Calculation ---")
    start_time = time.time()
    adapt_vqe = AdaptVQE(vqe_instance)
    # This temporary fix is needed for compatibility in some Qiskit versions
    adapt_vqe.supports_aux_operators = lambda: True
    
    solver_adapt = GroundStateEigensolver(mapper, adapt_vqe)
    result_adapt = solver_adapt.solve(problem)
    # Use problem.interpret to get the final energy
    final_adapt_result = problem.interpret(result_adapt)
    results['AdaptVQE'] = final_adapt_result.total_energies[0]
    print(f"AdaptVQE Energy: {results['AdaptVQE']:.8f} Hartree")
    print(f"AdaptVQE finished in {time.time() - start_time:.2f}s\n")

    # --- Final Summary ---
    print("\n" + "="*50)
    print("               Final Energy Summary for CH₄")
    print("="*50)
    print(f"  UHF Energy:          {results['UHF']:.8f} Hartree")
    print(f"  Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"  AdaptVQE Energy:     {results['AdaptVQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy:  {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum results to the exact FCI energy
    print(f"  Error (VQE vs FCI):    {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print(f"  Error (AdaptVQE vs FCI): {abs(results['AdaptVQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# CH₄ Ground State Calculation Comparison for Basis: sto-3g
# Started at: 2025-09-16 14:20:30
#
# --- Running Classical Calculations ---
# UHF Energy: -39.72680917 Hartree
# FCI (Exact) Energy: -39.80568529 Hartree
# Classical calculations finished in 1.14s
# /tmp/ipykernel_373981/3420063857.py:90: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_instance = VQE(Estimator(), ansatz, SLSQP())
# --- Running Standard VQE Calculation ---

# %%
import numpy as np
import time
from datetime import datetime

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports (Modern API) ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# --- Qiskit Algorithm Imports (Modern API) ---
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SLSQP
from qiskit.primitives import Estimator

# ----- Configuration -----
BASIS_SET = "sto-3g" # Using a minimal basis set for faster computation
BOND_LENGTH = 1.087  # Angstrom, standard C-H bond length for Methane

# ----- Main Calculation Function -----
def main():
    """
    Calculates the ground state energy of CH4 using three different methods:
    UHF, FCI, and standard VQE, using all electrons and orbitals.
    """
    print(f"CH₄ Ground State Calculation Comparison (Full System) for Basis: {BASIS_SET}")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    # Define the molecule's tetrahedral geometry
    val = BOND_LENGTH / np.sqrt(3)
    atom_str = (
        f"C 0.0000 0.0000 0.0000; "
        f"H {val:.4f} {val:.4f} {val:.4f}; "
        f"H {val:.4f} {-val:.4f} {-val:.4f}; "
        f"H {-val:.4f} {val:.4f} {-val:.4f}; "
        f"H {-val:.4f} {-val:.4f} {val:.4f}"
    )

    # Dictionary to store results
    results = {}

    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations ---")
    start_time = time.time()
    # Note: charge=0 for the neutral CH4 molecule
    mol = gto.M(atom=atom_str, basis=BASIS_SET, charge=0, spin=0, verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"UHF Energy: {results['UHF']:.8f} Hartree")
    
    # FCI Calculation
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum Calculation (VQE) ---
    
    # Set up the chemical problem for Qiskit, specifying charge=0
    driver = PySCFDriver(atom=atom_str, basis=BASIS_SET, charge=0, spin=0)
    problem = driver.run() # This is now the full problem
    
    mapper = JordanWignerMapper()

    # Define the UCCSD ansatz for VQE
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
        ),
    )

    # Define the VQE instance
    vqe_instance = VQE(Estimator(), ansatz, SLSQP())
    vqe_instance.initial_point = np.zeros(ansatz.num_parameters)

    # --- Standard VQE Calculation ---
    print("--- Running Standard VQE Calculation ---")
    start_time = time.time()
    solver_vqe = GroundStateEigensolver(mapper, vqe_instance)
    result_vqe = solver_vqe.solve(problem)
    
    # The total energy is directly available from the result, no interpretation needed
    results['VQE'] = result_vqe.total_energies[0]
    print(f"Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"VQE finished in {time.time() - start_time:.2f}s\n")

    # --- Final Summary ---
    print("\n" + "="*50)
    print("               Final Energy Summary for CH₄")
    print("="*50)
    print(f"  UHF Energy:          {results['UHF']:.8f} Hartree")
    print(f"  Standard VQE Energy: {results['VQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy:  {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare quantum result to the exact FCI energy
    print(f"  Error (VQE vs FCI):    {abs(results['VQE'] - results['FCI']):.8f} Hartree")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 15
#      12 from qiskit_nature.second_q.algorithms import GroundStateEigensolver
#      14 # --- Qiskit Algorithm Imports (Modern API) ---
# ---> 15 from qiskit_algorithms import VQE
#      16 from qiskit_algorithms.optimizers import SLSQP
#      17 from qiskit.primitives import Estimator
#
# ModuleNotFoundError: No module named 'qiskit_algorithms'

# %%
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt

# --- Classical Chemistry Imports (PySCF) ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.transformers import ActiveSpaceTransformer, FreezeCoreTransformer

# --- Qiskit Algorithm and Primitive Imports ---
# FIX: Using the reference Estimator from qiskit.primitives to ensure API
# compatibility with the VQE class and resolve the TypeError.
from qiskit.primitives import Estimator
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B

# ----- Configuration Parameters -----
BASIS_SET = "6-31g"
BOND_LENGTH = 0.9578  # O-H bond length in Angstrom
BOND_ANGLE = 104.478   # H-O-H angle in degrees

# ----- Helper Function -----
def get_h2o_geometry_string(bond_length=BOND_LENGTH, angle_deg=BOND_ANGLE):
    """Returns H₂O geometry as a PySCF-compatible string."""
    angle_rad = angle_deg * np.pi / 180
    x = bond_length * np.sin(angle_rad / 2)
    y = bond_length * np.cos(angle_rad / 2)
    return f"O 0.0 0.0 0.0; H {x} {y} 0.0; H {-x} {y} 0.0"

# ----- Main Execution -----
def main():
    """
    Calculates and compares the ground state energy of H₂O using
    UHF, FCI (exact), and VQE methods.
    """
    print(f"💧 H₂O Ground State Analysis (Basis: {BASIS_SET})")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    geometry_str = get_h2o_geometry_string()
    results = {}
    
    # --- 1. Classical Calculations (PySCF) ---
    print("--- Running Classical Calculations (PySCF) ---")
    start_time = time.time()
    
    # Setup the molecule for PySCF
    mol = gto.M(atom=geometry_str, basis=BASIS_SET, unit='angstrom', verbose=0)
    
    # Unrestricted Hartree-Fock (UHF) Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"  UHF Energy:              {-75.98634976:.8f} Hartree")
    
    # Full Configuration Interaction (FCI) Calculation - The exact answer
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"  FCI (Exact) Energy:      {-76.06555122:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. VQE Calculation (Qiskit Simulator) ---
    print("--- Running VQE Calculation (Qiskit Simulator) ---")
    start_time_vqe = time.time()

    # Setup Qiskit Nature problem
    driver = PySCFDriver(atom=geometry_str, unit=DistanceUnit.ANGSTROM, basis=BASIS_SET)
    problem = driver.run()

    # Define active space: freeze core electrons, keep 4 active electrons in 4 orbitals
    transformer = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
    problem = FreezeCoreTransformer(freeze_core=True).transform(problem)
    problem = transformer.transform(problem)
    
    mapper = ParityMapper(num_particles=problem.num_particles)
    qubit_op = problem.hamiltonian.second_q_op()

    # Setup VQE components
    intermediate_energies = []
    def callback(eval_count, parameters, mean, std):
        intermediate_energies.append(mean)
        print(f"  VQE Iteration {eval_count}: Energy = {mean:.8f}")

    estimator = Estimator()
    ansatz = UCCSD(
        problem.num_spatial_orbitals, problem.num_particles, mapper,
        initial_state=HartreeFock(problem.num_spatial_orbitals, problem.num_particles, mapper)
    )
    optimizer = L_BFGS_B(maxiter=1000)
    
    vqe = VQE(estimator, ansatz, optimizer, callback=callback)
    vqe_calc_result = vqe.compute_minimum_eigenvalue(qubit_op)
    
    # Interpret the result to get the final energy, including frozen core contributions
    vqe_energy = problem.interpret(vqe_calc_result).total_energies[0].real
    results['VQE'] = vqe_energy
    print(f"VQE calculation finished in {time.time() - start_time_vqe:.2f}s")
    
    # --- 3. Final Summary ---
    print("\n" + "="*50)
    print("           Final Energy Summary")
    print("="*50)
    print(f"  UHF Energy:         {results['UHF']:.8f} Hartree")
    print(f"  VQE Energy:         {results['VQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare the final quantum result to the exact FCI energy
    error = abs(results['VQE'] - results['FCI'])
    print(f"  Error (VQE vs. FCI): {error:.8f} Hartree")
    print("="*50)

    # --- 4. Plot VQE Convergence ---
    plt.figure(figsize=(10, 6))
    plt.plot(intermediate_energies, 'o-', label="VQE Energy per Iteration", color='dodgerblue')
    # Plot the exact FCI energy as a reference line
    plt.axhline(y=results['FCI'], color='r', linestyle='--', label="FCI (Exact) Energy")
    plt.xlabel("Optimizer Iteration")
    plt.ylabel("Energy (Hartree)")
    plt.title("VQE Convergence for H₂O Molecule")
    plt.legend()
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 10
#       7 from pyscf import gto, scf, fci
#       9 # --- Qiskit Nature Imports ---
# ---> 10 from qiskit_nature.second_q.drivers import PySCFDriver
#      11 from qiskit_nature.units import DistanceUnit
#      12 from qiskit_nature.second_q.mappers import ParityMapper
#
# File ~/miniconda3/envs/qiskit-env/lib/python3.11/site-packages/qiskit_nature/__init__.py:53
#       1 # This code is part of a Qiskit project.
#       2 #
#       3 # (C) Copyright IBM 2018, 2023.
#    (...)     10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      12 r"""
#      13 =============================================
#      14 Qiskit Nature module (:mod:`qiskit_nature`)
#    (...)     50
#      51 """
# ---> 53 from qiskit_algorithms.list_or_dict import ListOrDict as ListOrDictType
#      55 from .exceptions import QiskitNatureError, UnsupportMethodError
#      56 from .logging import logging
#
# File ~/miniconda3/envs/qiskit-env/lib/python3.11/site-packages/qiskit_algorithms/__init__.py:307
#     282 from .time_evolvers import (
#     283     ImaginaryTimeEvolver,
#     284     RealTimeEvolver,
#    (...)    295     VarQTEResult,
#     296 )
#     298 from .eigensolvers import (
#     299     Eigensolver,
#     300     EigensolverResult,
#    (...)    304     VQDResult,
#     305 )
# --> 307 from .minimum_eigensolvers import (
#     308     AdaptVQE,
#     309     AdaptVQEResult,
#     310     MinimumEigensolver,
#     311     MinimumEigensolverResult,
#     312     NumPyMinimumEigensolver,
#     313     NumPyMinimumEigensolverResult,
#     314     QAOA,
#     315     SamplingMinimumEigensolver,
#     316     SamplingMinimumEigensolverResult,
#     317     SamplingVQE,
#     318     SamplingVQEResult,
#     319     VQE,
#     320     VQEResult,
#     321 )
#     323 from .version import __version__
#     325 __all__ = [
#     326     "__version__",
#     327     "AlgorithmJob",
#    (...)    386     "VQEResult",
#     387 ]
#
# File ~/miniconda3/envs/qiskit-env/lib/python3.11/site-packages/qiskit_algorithms/minimum_eigensolvers/__init__.py:15
#       1 # This code is part of a Qiskit project.
#       2 #
#       3 # (C) Copyright IBM 2022, 2023.
#    (...)     10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """The Minimum Eigensolvers package."""
# ---> 15 from .adapt_vqe import AdaptVQE, AdaptVQEResult
#      16 from .minimum_eigensolver import MinimumEigensolver, MinimumEigensolverResult
#      17 from .numpy_minimum_eigensolver import NumPyMinimumEigensolver, NumPyMinimumEigensolverResult
#
# File ~/miniconda3/envs/qiskit-env/lib/python3.11/site-packages/qiskit_algorithms/minimum_eigensolvers/adapt_vqe.py:25
#      23 import numpy as np
#      24 from qiskit import QuantumCircuit
# ---> 25 from qiskit.circuit.library import EvolvedOperatorAnsatz, evolved_operator_ansatz
#      26 from qiskit.quantum_info import SparsePauliOp
#      27 from qiskit.quantum_info.operators.base_operator import BaseOperator
#
# ImportError: cannot import name 'evolved_operator_ansatz' from 'qiskit.circuit.library' (/config/miniconda3/envs/qiskit-env/lib/python3.11/site-packages/qiskit/circuit/library/__init__.py)

# %%
# !pip list|grep qiskit
# Out:
# qiskit                  1.1.0
# qiskit-algorithms       0.4.0
# qiskit-nature           0.7.2

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /config/miniconda3/envs/qiskit-env/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /config/miniconda3/envs/qiskit-env/lib/python3.11/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.4-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /config/miniconda3/envs/qiskit-env/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /config/miniconda3/envs/qiskit-env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.6-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 21.5 MB/s  0:00:00m0:00:0100:01
# Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 35.5 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.6 MB/s  0:00:00
# Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 44.4 MB/s  0:00:00
# Downloading pyparsing-3.2.4-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.10.6 pillow-11.3.0 pyparsing-3.2.4

# %%
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt

# --- Classical Chemistry Imports ---
from pyscf import gto, scf, fci

# --- Qiskit Nature Imports ---
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.mappers import JordanWignerMapper # Changed to JordanWignerMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.transformers import ActiveSpaceTransformer, FreezeCoreTransformer

# --- Qiskit Aer and Algorithms Imports ---
from qiskit_aer.primitives import Estimator as AerEstimator
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B

# ----- Configuration Parameters -----
BASIS_SET = "6-31g"
BOND_LENGTH = 0.9578  # O-H bond length in Angstrom
BOND_ANGLE = 104.478   # H-O-H angle in degrees

# ----- Helper Function -----
def get_h2o_geometry(bond_length=BOND_LENGTH, angle_deg=BOND_ANGLE):
    """Returns H₂O geometry as a PySCF-compatible string."""
    angle_rad = angle_deg * np.pi / 180
    x = bond_length * np.sin(angle_rad / 2)
    y = bond_length * np.cos(angle_rad / 2)
    # Format for PySCF gto.M object
    return f"O 0.0 0.0 0.0; H {x} {y} 0.0; H {-x} {y} 0.0"

# ----- Main Execution -----
def main():
    """
    Calculates and compares the ground state energy of H₂O using
    classical (UHF, FCI) and quantum (VQE) methods.
    """
    print(f"💧 H₂O Ground State Analysis (Basis: {BASIS_SET})")
    print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

    geometry_str = get_h2o_geometry()
    results = {}
    
    # --- 1. Classical Calculations (UHF and FCI) ---
    print("--- Running Classical Calculations (PySCF) ---")
    start_time = time.time()
    # PySCF Molecule object
    mol = gto.M(atom=geometry_str, basis=BASIS_SET, unit='angstrom', verbose=0)
    
    # UHF Calculation
    mf_uhf = scf.UHF(mol).run()
    results['UHF'] = mf_uhf.e_tot
    print(f"  UHF Energy:              {results['UHF']:.8f} Hartree")
    
    # FCI Calculation (Exact Energy)
    mf_rhf = scf.RHF(mol).run()
    results['FCI'] = fci.FCI(mol, mf_rhf.mo_coeff).kernel()[0]
    print(f"  FCI (Exact) Energy:      {results['FCI']:.8f} Hartree")
    print(f"Classical calculations finished in {time.time() - start_time:.2f}s\n")

    # --- 2. Quantum VQE Calculation ---
    print("--- Running VQE Calculation (Qiskit Aer Simulator) ---")
    start_time = time.time()
    
    # Set up the problem for Qiskit Nature
    driver = PySCFDriver(atom=geometry_str, unit=DistanceUnit.ANGSTROM, basis=BASIS_SET)
    problem = driver.run()
    
    # Define active space and transformers
    # Freezing the core 1s orbital of Oxygen
    problem = FreezeCoreTransformer().transform(problem)
    # Using a (4 electron, 4 orbital) active space for feasibility
    transformer = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
    problem = transformer.transform(problem)
    
    # Map from fermionic to qubit operators
    mapper = JordanWignerMapper()
    qubit_op = mapper.map(problem.hamiltonian.second_q_op())
    
    # Set up the VQE algorithm components
    estimator = AerEstimator()
    optimizer = L_BFGS_B(maxiter=1000)
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            mapper
        )
    )
    
    # A callback to see the optimization progress
    intermediate_values = []
    def callback(eval_count, parameters, mean, std):
        intermediate_values.append(mean)
        print(f"  VQE Iteration {eval_count}: Energy = {mean:.8f} Ha")

    vqe = VQE(estimator, ansatz, optimizer, callback=callback)
    vqe_calc_result = vqe.compute_minimum_eigenvalue(qubit_op)
    
    # Interpret the result to get the final energy, including frozen core contributions
    vqe_energy = problem.interpret(vqe_calc_result).total_energies[0].real
    results['VQE'] = vqe_energy
    
    print(f"VQE calculation finished in {time.time() - start_time:.2f}s\n")
    
    # --- 3. Final Summary ---
    print("\n" + "="*50)
    print("           Final Energy Summary")
    print("="*50)
    print(f"  UHF Energy:         {results['UHF']:.8f} Hartree")
    print(f"  VQE Energy:         {results['VQE']:.8f} Hartree")
    print(f"  FCI (Exact) Energy: {results['FCI']:.8f} Hartree")
    print("-" * 50)
    # Compare the VQE result to the exact FCI energy
    error = abs(results['VQE'] - results['FCI'])
    print(f"  Error (VQE vs FCI): {error:.8f} Hartree")
    print("="*50)
    
    # --- 4. Plot Convergence ---
    plt.figure(figsize=(10, 6))
    plt.plot(intermediate_values, 'o-', color='royalblue', label='VQE Energy')
    plt.axhline(y=results['FCI'], color='r', linestyle='--', label='FCI (Exact) Energy')
    # This is the exact energy within the active space, which VQE should approach
    exact_active_space_energy = problem.interpret(vqe_calc_result).ground_energy + problem.reference_energy
    plt.axhline(y=exact_active_space_energy, color='g', linestyle='--', label='Exact Active Space Energy')
    plt.title('VQE Convergence for H₂O')
    plt.xlabel('Optimizer Iteration')
    plt.ylabel('Energy (Hartree)')
    plt.legend()
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# 💧 H₂O Ground State Analysis (Basis: 6-31g)
# Started at: 2025-09-19 10:27:03
#
# --- Running Classical Calculations (PySCF) ---
#   UHF Energy:              -75.98397342 Hartree
#   FCI (Exact) Energy:      -76.12087584 Hartree
# Classical calculations finished in 7.42s
#
# --- Running VQE Calculation (Qiskit Aer Simulator) ---
# /tmp/ipykernel_1610445/1702491179.py:140: DeprecationWarning: Estimator has been deprecated as of Aer 0.15, please use EstimatorV2 instead.
#   main()
# /tmp/ipykernel_1610445/1702491179.py:140: DeprecationWarning: Option approximation=False is deprecated as of qiskit-aer 0.13. It will be removed no earlier than 3 months after the release date. Instead, use BackendEstimator from qiskit.primitives.
#   main()
#   VQE Iteration 1: Energy = -5.03330617 Ha
#   VQE Iteration 2: Energy = -5.10381004 Ha
#   VQE Iteration 3: Energy = -5.07804331 Ha
#   VQE Iteration 4: Energy = -5.03899089 Ha
#   VQE Iteration 5: Energy = -5.07670093 Ha
#   VQE Iteration 6: Energy = -5.06161487 Ha
#   VQE Iteration 7: Energy = -5.06075158 Ha
#   VQE Iteration 8: Energy = -5.11743898 Ha
#   VQE Iteration 9: Energy = -5.04842873 Ha
#   VQE Iteration 10: Energy = -5.00763500 Ha
#   VQE Iteration 11: Energy = -5.07709642 Ha
#   VQE Iteration 12: Energy = -5.07152735 Ha
#   VQE Iteration 13: Energy = -5.04949497 Ha
#   VQE Iteration 14: Energy = -5.08930676 Ha
#   VQE Iteration 15: Energy = -5.04243745 Ha
#   VQE Iteration 16: Energy = -5.11499894 Ha
#   VQE Iteration 17: Energy = -5.04165684 Ha
#   VQE Iteration 18: Energy = -5.13332486 Ha
#   VQE Iteration 19: Energy = -5.07932926 Ha
#   VQE Iteration 20: Energy = -5.11809458 Ha
#   VQE Iteration 21: Energy = -5.06863292 Ha
#   VQE Iteration 22: Energy = -5.05455796 Ha
#   VQE Iteration 23: Energy = -5.11003599 Ha
#   VQE Iteration 24: Energy = -5.04238747 Ha
#   VQE Iteration 25: Energy = -5.08588428 Ha
#   VQE Iteration 26: Energy = -5.03450795 Ha
#   VQE Iteration 27: Energy = -5.09713001 Ha
#   VQE Iteration 28: Energy = -4.98347136 Ha
#   VQE Iteration 29: Energy = -4.90367844 Ha
#   VQE Iteration 30: Energy = -4.99456029 Ha
#   VQE Iteration 31: Energy = -4.95221322 Ha
#   VQE Iteration 32: Energy = -4.99506726 Ha
#   VQE Iteration 33: Energy = -4.97108736 Ha
#   VQE Iteration 34: Energy = -4.96476387 Ha
#   VQE Iteration 35: Energy = -4.95646499 Ha
#   VQE Iteration 36: Energy = -4.95895721 Ha
#   VQE Iteration 37: Energy = -4.98033058 Ha
#   VQE Iteration 38: Energy = -4.94936775 Ha
#   VQE Iteration 39: Energy = -4.98471174 Ha
#   VQE Iteration 40: Energy = -4.97236602 Ha
#   VQE Iteration 41: Energy = -4.97326533 Ha
#   VQE Iteration 42: Energy = -5.03258369 Ha
#   VQE Iteration 43: Energy = -5.02653396 Ha
#   VQE Iteration 44: Energy = -4.97191879 Ha
#   VQE Iteration 45: Energy = -4.94102565 Ha
#   VQE Iteration 46: Energy = -4.90643522 Ha
#   VQE Iteration 47: Energy = -5.00315034 Ha
#   VQE Iteration 48: Energy = -4.98314160 Ha
#   VQE Iteration 49: Energy = -4.98051878 Ha
#   VQE Iteration 50: Energy = -4.93714898 Ha
#   VQE Iteration 51: Energy = -4.93787506 Ha
#   VQE Iteration 52: Energy = -4.99262012 Ha
#   VQE Iteration 53: Energy = -5.02328320 Ha
#   VQE Iteration 54: Energy = -4.95747267 Ha
#   VQE Iteration 55: Energy = -5.01629022 Ha
#   VQE Iteration 56: Energy = -5.06400700 Ha
#   VQE Iteration 57: Energy = -4.99462890 Ha
#   VQE Iteration 58: Energy = -4.98346184 Ha
#   VQE Iteration 59: Energy = -5.04103112 Ha
#   VQE Iteration 60: Energy = -4.95659072 Ha
#   VQE Iteration 61: Energy = -5.01119222 Ha
#   VQE Iteration 62: Energy = -5.03679685 Ha
#   VQE Iteration 63: Energy = -4.98362076 Ha
#   VQE Iteration 64: Energy = -4.99771296 Ha
#   VQE Iteration 65: Energy = -5.02071203 Ha
#   VQE Iteration 66: Energy = -4.97683656 Ha
#   VQE Iteration 67: Energy = -5.05887417 Ha
#   VQE Iteration 68: Energy = -5.01228311 Ha
#   VQE Iteration 69: Energy = -4.99781569 Ha
#   VQE Iteration 70: Energy = -4.94585466 Ha
#   VQE Iteration 71: Energy = -5.00287744 Ha
#   VQE Iteration 72: Energy = -5.00115554 Ha
#   VQE Iteration 73: Energy = -5.00012480 Ha
#   VQE Iteration 74: Energy = -5.05462920 Ha
#   VQE Iteration 75: Energy = -5.06525628 Ha
#   VQE Iteration 76: Energy = -5.04353183 Ha
#   VQE Iteration 77: Energy = -4.99634324 Ha
#   VQE Iteration 78: Energy = -5.02148527 Ha
#   VQE Iteration 79: Energy = -5.01898863 Ha
#   VQE Iteration 80: Energy = -5.03887383 Ha
#   VQE Iteration 81: Energy = -5.00080758 Ha
#   VQE Iteration 82: Energy = -5.07697929 Ha
#   VQE Iteration 83: Energy = -5.07043290 Ha
#   VQE Iteration 84: Energy = -5.01205082 Ha
#   VQE Iteration 85: Energy = -5.03776351 Ha
#   VQE Iteration 86: Energy = -5.08378829 Ha
#   VQE Iteration 87: Energy = -5.07379122 Ha
#   VQE Iteration 88: Energy = -4.98914782 Ha
#   VQE Iteration 89: Energy = -5.05617167 Ha
#   VQE Iteration 90: Energy = -5.06641881 Ha
#   VQE Iteration 91: Energy = -5.03159238 Ha
#   VQE Iteration 92: Energy = -5.05395581 Ha
#   VQE Iteration 93: Energy = -5.04840951 Ha
#   VQE Iteration 94: Energy = -5.05028621 Ha
#   VQE Iteration 95: Energy = -5.05282787 Ha
#   VQE Iteration 96: Energy = -5.03261568 Ha
#   VQE Iteration 97: Energy = -5.04080997 Ha
#   VQE Iteration 98: Energy = -5.03212634 Ha
#   VQE Iteration 99: Energy = -5.07876447 Ha
#   VQE Iteration 100: Energy = -5.07064337 Ha
#   VQE Iteration 101: Energy = -5.10680971 Ha
#   VQE Iteration 102: Energy = -5.05838811 Ha
#   VQE Iteration 103: Energy = -5.09289316 Ha
#   VQE Iteration 104: Energy = -5.01997369 Ha
#   VQE Iteration 105: Energy = -5.06738242 Ha
#   VQE Iteration 106: Energy = -5.00786002 Ha
#   VQE Iteration 107: Energy = -5.10868786 Ha
#   VQE Iteration 108: Energy = -5.07674925 Ha
#   VQE Iteration 109: Energy = -5.05775953 Ha
#   VQE Iteration 110: Energy = -5.07739371 Ha
#   VQE Iteration 111: Energy = -5.06414918 Ha
#   VQE Iteration 112: Energy = -5.03590674 Ha
#   VQE Iteration 113: Energy = -5.07411583 Ha
#   VQE Iteration 114: Energy = -5.11839918 Ha
#   VQE Iteration 115: Energy = -5.06209570 Ha
#   VQE Iteration 116: Energy = -5.06673391 Ha
#   VQE Iteration 117: Energy = -5.04942065 Ha
#   VQE Iteration 118: Energy = -5.05375848 Ha
#   VQE Iteration 119: Energy = -5.07952054 Ha
#   VQE Iteration 120: Energy = -5.10225380 Ha
#   VQE Iteration 121: Energy = -5.11953684 Ha
#   VQE Iteration 122: Energy = -5.09565732 Ha
#   VQE Iteration 123: Energy = -5.03584380 Ha
#   VQE Iteration 124: Energy = -5.06959191 Ha
#   VQE Iteration 125: Energy = -5.04691865 Ha
#   VQE Iteration 126: Energy = -5.01738811 Ha
#   VQE Iteration 127: Energy = -5.06568884 Ha
#   VQE Iteration 128: Energy = -5.05532898 Ha
#   VQE Iteration 129: Energy = -5.04776334 Ha
#   VQE Iteration 130: Energy = -5.03651535 Ha
#   VQE Iteration 131: Energy = -5.07462544 Ha
#   VQE Iteration 132: Energy = -5.12661206 Ha
#   VQE Iteration 133: Energy = -5.08113781 Ha
#   VQE Iteration 134: Energy = -5.06657394 Ha
#   VQE Iteration 135: Energy = -5.06907411 Ha
#   VQE Iteration 136: Energy = -5.03598326 Ha
#   VQE Iteration 137: Energy = -5.09727472 Ha
#   VQE Iteration 138: Energy = -5.10299566 Ha
#   VQE Iteration 139: Energy = -5.07571030 Ha
#   VQE Iteration 140: Energy = -5.10471475 Ha
#   VQE Iteration 141: Energy = -5.10750847 Ha
#   VQE Iteration 142: Energy = -5.08027470 Ha
#   VQE Iteration 143: Energy = -5.03819475 Ha
#   VQE Iteration 144: Energy = -5.07920659 Ha
#   VQE Iteration 145: Energy = -5.05623661 Ha
#   VQE Iteration 146: Energy = -5.07370342 Ha
#   VQE Iteration 147: Energy = -5.04461282 Ha
#   VQE Iteration 148: Energy = -5.05728510 Ha
#   VQE Iteration 149: Energy = -5.10242330 Ha
#   VQE Iteration 150: Energy = -5.02710402 Ha
#   VQE Iteration 151: Energy = -5.07072298 Ha
#   VQE Iteration 152: Energy = -5.04204379 Ha
#   VQE Iteration 153: Energy = -5.05993606 Ha
#   VQE Iteration 154: Energy = -5.06180281 Ha
#   VQE Iteration 155: Energy = -5.07616625 Ha
#   VQE Iteration 156: Energy = -5.06273735 Ha
#   VQE Iteration 157: Energy = -5.03089957 Ha
#   VQE Iteration 158: Energy = -5.07037955 Ha
#   VQE Iteration 159: Energy = -5.08723210 Ha
#   VQE Iteration 160: Energy = -5.09844376 Ha
#   VQE Iteration 161: Energy = -5.09552918 Ha
#   VQE Iteration 162: Energy = -5.04631756 Ha
#   VQE Iteration 163: Energy = -5.04909713 Ha
#   VQE Iteration 164: Energy = -5.07442951 Ha
#   VQE Iteration 165: Energy = -5.04911294 Ha
#   VQE Iteration 166: Energy = -5.10646875 Ha
#   VQE Iteration 167: Energy = -5.07949778 Ha
#   VQE Iteration 168: Energy = -5.05868108 Ha
#   VQE Iteration 169: Energy = -5.01847843 Ha
#   VQE Iteration 170: Energy = -5.06963957 Ha
#   VQE Iteration 171: Energy = -5.07149737 Ha
#   VQE Iteration 172: Energy = -5.06889279 Ha
#   VQE Iteration 173: Energy = -5.09453071 Ha
#   VQE Iteration 174: Energy = -5.11430156 Ha
#   VQE Iteration 175: Energy = -5.06124744 Ha
#   VQE Iteration 176: Energy = -5.04383909 Ha
#   VQE Iteration 177: Energy = -5.11762009 Ha
#   VQE Iteration 178: Energy = -5.10534964 Ha
#   VQE Iteration 179: Energy = -5.06524148 Ha
#   VQE Iteration 180: Energy = -5.08993636 Ha
#   VQE Iteration 181: Energy = -5.08323467 Ha
#   VQE Iteration 182: Energy = -5.04879591 Ha
#   VQE Iteration 183: Energy = -5.01866916 Ha
#   VQE Iteration 184: Energy = -5.07921569 Ha
#   VQE Iteration 185: Energy = -5.03825251 Ha
#   VQE Iteration 186: Energy = -5.01657486 Ha
#   VQE Iteration 187: Energy = -5.08463740 Ha
#   VQE Iteration 188: Energy = -5.04910810 Ha
#   VQE Iteration 189: Energy = -5.08223872 Ha
#   VQE Iteration 190: Energy = -5.04272390 Ha
#   VQE Iteration 191: Energy = -5.10091555 Ha
#   VQE Iteration 192: Energy = -5.04390911 Ha
#   VQE Iteration 193: Energy = -5.07345502 Ha
#   VQE Iteration 194: Energy = -5.08528982 Ha
#   VQE Iteration 195: Energy = -5.09115368 Ha
#   VQE Iteration 196: Energy = -5.01838418 Ha
#   VQE Iteration 197: Energy = -5.03281226 Ha
#   VQE Iteration 198: Energy = -5.14033455 Ha
#   VQE Iteration 199: Energy = -5.07234935 Ha
#   VQE Iteration 200: Energy = -5.03028865 Ha
#   VQE Iteration 201: Energy = -5.04580726 Ha
#   VQE Iteration 202: Energy = -5.08708778 Ha
#   VQE Iteration 203: Energy = -5.06523415 Ha
#   VQE Iteration 204: Energy = -5.05875250 Ha
#   VQE Iteration 205: Energy = -5.07685919 Ha
#   VQE Iteration 206: Energy = -5.02975899 Ha
#   VQE Iteration 207: Energy = -5.07022131 Ha
#   VQE Iteration 208: Energy = -5.09932438 Ha
#   VQE Iteration 209: Energy = -5.07383171 Ha
#   VQE Iteration 210: Energy = -5.09294331 Ha
#   VQE Iteration 211: Energy = -5.04767401 Ha
#   VQE Iteration 212: Energy = -5.10870396 Ha
#   VQE Iteration 213: Energy = -5.08208746 Ha
#   VQE Iteration 214: Energy = -5.05426907 Ha
#   VQE Iteration 215: Energy = -5.07338492 Ha
#   VQE Iteration 216: Energy = -5.10971231 Ha
#   VQE Iteration 217: Energy = -5.10997533 Ha
#   VQE Iteration 218: Energy = -5.06879692 Ha
#   VQE Iteration 219: Energy = -5.07133896 Ha
#   VQE Iteration 220: Energy = -5.06770138 Ha
#   VQE Iteration 221: Energy = -5.06335816 Ha
#   VQE Iteration 222: Energy = -5.06960254 Ha
#   VQE Iteration 223: Energy = -5.09984607 Ha
#   VQE Iteration 224: Energy = -5.10886039 Ha
#   VQE Iteration 225: Energy = -5.12158630 Ha
#   VQE Iteration 226: Energy = -5.10931287 Ha
#   VQE Iteration 227: Energy = -5.08911212 Ha
#   VQE Iteration 228: Energy = -5.07310002 Ha
#   VQE Iteration 229: Energy = -5.09002317 Ha
#   VQE Iteration 230: Energy = -5.06315770 Ha
#   VQE Iteration 231: Energy = -5.07473674 Ha
#   VQE Iteration 232: Energy = -5.08844030 Ha
#   VQE Iteration 233: Energy = -5.07715030 Ha
#   VQE Iteration 234: Energy = -5.05314871 Ha
#   VQE Iteration 235: Energy = -5.05615240 Ha
#   VQE Iteration 236: Energy = -5.07088867 Ha
#   VQE Iteration 237: Energy = -5.06441516 Ha
#   VQE Iteration 238: Energy = -5.01482824 Ha
#   VQE Iteration 239: Energy = -5.05937466 Ha
#   VQE Iteration 240: Energy = -5.06302578 Ha
#   VQE Iteration 241: Energy = -5.09163993 Ha
#   VQE Iteration 242: Energy = -5.04597241 Ha
#   VQE Iteration 243: Energy = -5.07938109 Ha
#   VQE Iteration 244: Energy = -5.05535698 Ha
#   VQE Iteration 245: Energy = -5.12700041 Ha
#   VQE Iteration 246: Energy = -5.06900740 Ha
#   VQE Iteration 247: Energy = -5.07025263 Ha
#   VQE Iteration 248: Energy = -5.02228507 Ha
#   VQE Iteration 249: Energy = -4.99095831 Ha
#   VQE Iteration 250: Energy = -5.12448738 Ha
#   VQE Iteration 251: Energy = -5.05570641 Ha
#   VQE Iteration 252: Energy = -5.11050812 Ha
#   VQE Iteration 253: Energy = -5.11709030 Ha
#   VQE Iteration 254: Energy = -5.07787486 Ha
#   VQE Iteration 255: Energy = -5.09461419 Ha
#   VQE Iteration 256: Energy = -5.05245381 Ha
#   VQE Iteration 257: Energy = -5.10048141 Ha
#   VQE Iteration 258: Energy = -5.05701489 Ha
#   VQE Iteration 259: Energy = -5.12248401 Ha
#   VQE Iteration 260: Energy = -5.07839288 Ha
#   VQE Iteration 261: Energy = -5.08194276 Ha
#   VQE Iteration 262: Energy = -5.11348574 Ha
#   VQE Iteration 263: Energy = -5.06738549 Ha
#   VQE Iteration 264: Energy = -5.11346580 Ha
#   VQE Iteration 265: Energy = -5.08578032 Ha
#   VQE Iteration 266: Energy = -5.10969477 Ha
#   VQE Iteration 267: Energy = -5.10050812 Ha
#   VQE Iteration 268: Energy = -5.10483806 Ha
#   VQE Iteration 269: Energy = -5.11063152 Ha
#   VQE Iteration 270: Energy = -5.08946024 Ha
#   VQE Iteration 271: Energy = -5.07569220 Ha
#   VQE Iteration 272: Energy = -5.04722280 Ha
#   VQE Iteration 273: Energy = -5.06991016 Ha
#   VQE Iteration 274: Energy = -5.04813492 Ha
#   VQE Iteration 275: Energy = -5.10992530 Ha
#   VQE Iteration 276: Energy = -5.10320117 Ha
#   VQE Iteration 277: Energy = -5.10342985 Ha
#   VQE Iteration 278: Energy = -5.06749971 Ha
#   VQE Iteration 279: Energy = -5.10120772 Ha
#   VQE Iteration 280: Energy = -5.05458899 Ha
#   VQE Iteration 281: Energy = -5.09619784 Ha
#   VQE Iteration 282: Energy = -5.05689926 Ha
#   VQE Iteration 283: Energy = -5.07644575 Ha
#   VQE Iteration 284: Energy = -5.03166638 Ha
#   VQE Iteration 285: Energy = -5.07081120 Ha
#   VQE Iteration 286: Energy = -5.09425606 Ha
#   VQE Iteration 287: Energy = -5.04530424 Ha
#   VQE Iteration 288: Energy = -5.08577841 Ha
#   VQE Iteration 289: Energy = -5.08893864 Ha
#   VQE Iteration 290: Energy = -5.04390969 Ha
#   VQE Iteration 291: Energy = -5.04845124 Ha
#   VQE Iteration 292: Energy = -5.09957045 Ha
#   VQE Iteration 293: Energy = -5.06811704 Ha
#   VQE Iteration 294: Energy = -5.05615370 Ha
#   VQE Iteration 295: Energy = -5.07842825 Ha
#   VQE Iteration 296: Energy = -5.04148863 Ha
#   VQE Iteration 297: Energy = -5.07831464 Ha
#   VQE Iteration 298: Energy = -5.04746019 Ha
#   VQE Iteration 299: Energy = -5.06227605 Ha
#   VQE Iteration 300: Energy = -5.04459632 Ha
#   VQE Iteration 301: Energy = -5.03109621 Ha
#   VQE Iteration 302: Energy = -5.11503785 Ha
#   VQE Iteration 303: Energy = -5.03403172 Ha
#   VQE Iteration 304: Energy = -5.06578704 Ha
#   VQE Iteration 305: Energy = -5.06972555 Ha
#   VQE Iteration 306: Energy = -5.06520116 Ha
#   VQE Iteration 307: Energy = -5.03908128 Ha
#   VQE Iteration 308: Energy = -5.09439874 Ha
#   VQE Iteration 309: Energy = -5.05560869 Ha
#   VQE Iteration 310: Energy = -5.05300822 Ha
#   VQE Iteration 311: Energy = -5.10653189 Ha
#   VQE Iteration 312: Energy = -5.03072598 Ha
#   VQE Iteration 313: Energy = -5.10115061 Ha
#   VQE Iteration 314: Energy = -5.04076824 Ha
#   VQE Iteration 315: Energy = -5.08108177 Ha
#   VQE Iteration 316: Energy = -5.07655061 Ha
#   VQE Iteration 317: Energy = -5.09450546 Ha
#   VQE Iteration 318: Energy = -5.06048888 Ha
#   VQE Iteration 319: Energy = -5.08972539 Ha
#   VQE Iteration 320: Energy = -5.05987280 Ha
#   VQE Iteration 321: Energy = -5.08235823 Ha
#   VQE Iteration 322: Energy = -5.04510928 Ha
#   VQE Iteration 323: Energy = -5.05479415 Ha
#   VQE Iteration 324: Energy = -5.01875859 Ha
#   VQE Iteration 325: Energy = -5.03954118 Ha
#   VQE Iteration 326: Energy = -5.09813761 Ha
#   VQE Iteration 327: Energy = -5.07298350 Ha
#   VQE Iteration 328: Energy = -5.04399515 Ha
#   VQE Iteration 329: Energy = -5.11719318 Ha
#   VQE Iteration 330: Energy = -5.07055256 Ha
#   VQE Iteration 331: Energy = -5.07714083 Ha
#   VQE Iteration 332: Energy = -5.09110342 Ha
#   VQE Iteration 333: Energy = -5.02188304 Ha
#   VQE Iteration 334: Energy = -5.05538058 Ha
#   VQE Iteration 335: Energy = -5.04184784 Ha
#   VQE Iteration 336: Energy = -5.10743592 Ha
#   VQE Iteration 337: Energy = -5.11940370 Ha
#   VQE Iteration 338: Energy = -5.12403710 Ha
#   VQE Iteration 339: Energy = -5.11507625 Ha
#   VQE Iteration 340: Energy = -5.10870158 Ha
#   VQE Iteration 341: Energy = -5.06456186 Ha
#   VQE Iteration 342: Energy = -5.07325040 Ha
#   VQE Iteration 343: Energy = -5.04417869 Ha
#   VQE Iteration 344: Energy = -5.03387923 Ha
#   VQE Iteration 345: Energy = -5.05494191 Ha
#   VQE Iteration 346: Energy = -5.05035709 Ha
#   VQE Iteration 347: Energy = -5.08428115 Ha
#   VQE Iteration 348: Energy = -5.10556852 Ha
#   VQE Iteration 349: Energy = -5.12209096 Ha
#   VQE Iteration 350: Energy = -5.08201008 Ha
#   VQE Iteration 351: Energy = -5.05038474 Ha
#   VQE Iteration 352: Energy = -5.05413843 Ha
#   VQE Iteration 353: Energy = -4.98993348 Ha
#   VQE Iteration 354: Energy = -5.05215671 Ha
#   VQE Iteration 355: Energy = -5.08868062 Ha
#   VQE Iteration 356: Energy = -5.12019383 Ha
#   VQE Iteration 357: Energy = -5.09830438 Ha
#   VQE Iteration 358: Energy = -5.06027030 Ha
#   VQE Iteration 359: Energy = -5.13983641 Ha
#   VQE Iteration 360: Energy = -5.04741899 Ha
#   VQE Iteration 361: Energy = -5.08992579 Ha
#   VQE Iteration 362: Energy = -5.04155984 Ha
#   VQE Iteration 363: Energy = -5.07511995 Ha
#   VQE Iteration 364: Energy = -5.10071631 Ha
#   VQE Iteration 365: Energy = -5.04974250 Ha
#   VQE Iteration 366: Energy = -5.09236044 Ha
#   VQE Iteration 367: Energy = -5.06673298 Ha
#   VQE Iteration 368: Energy = -5.08466001 Ha
#   VQE Iteration 369: Energy = -5.08755023 Ha
#   VQE Iteration 370: Energy = -5.06455625 Ha
#   VQE Iteration 371: Energy = -5.08941016 Ha
#   VQE Iteration 372: Energy = -5.07147989 Ha
#   VQE Iteration 373: Energy = -5.01507030 Ha
#   VQE Iteration 374: Energy = -5.04094448 Ha
#   VQE Iteration 375: Energy = -5.03956489 Ha
#   VQE Iteration 376: Energy = -5.12484425 Ha
#   VQE Iteration 377: Energy = -5.05765676 Ha
#   VQE Iteration 378: Energy = -5.05793475 Ha
#   VQE Iteration 379: Energy = -5.09188968 Ha
#   VQE Iteration 380: Energy = -5.05506361 Ha
#   VQE Iteration 381: Energy = -5.10875329 Ha
#   VQE Iteration 382: Energy = -5.06994373 Ha
#   VQE Iteration 383: Energy = -5.06644225 Ha
#   VQE Iteration 384: Energy = -5.07149803 Ha
#   VQE Iteration 385: Energy = -5.07054886 Ha
#   VQE Iteration 386: Energy = -5.08796466 Ha
#   VQE Iteration 387: Energy = -5.03389808 Ha
#   VQE Iteration 388: Energy = -5.04369757 Ha
#   VQE Iteration 389: Energy = -5.14893475 Ha
#   VQE Iteration 390: Energy = -5.09406172 Ha
#   VQE Iteration 391: Energy = -5.05234921 Ha
#   VQE Iteration 392: Energy = -5.00971241 Ha
#   VQE Iteration 393: Energy = -5.09629520 Ha
#   VQE Iteration 394: Energy = -5.10666327 Ha
#   VQE Iteration 395: Energy = -5.01313491 Ha
#   VQE Iteration 396: Energy = -5.11729395 Ha
#   VQE Iteration 397: Energy = -5.03848928 Ha
#   VQE Iteration 398: Energy = -5.09113996 Ha
#   VQE Iteration 399: Energy = -5.09124307 Ha
#   VQE Iteration 400: Energy = -5.03333517 Ha
#   VQE Iteration 401: Energy = -5.05153842 Ha
#   VQE Iteration 402: Energy = -5.02228710 Ha
#   VQE Iteration 403: Energy = -5.08606545 Ha
#   VQE Iteration 404: Energy = -5.06275094 Ha
#   VQE Iteration 405: Energy = -5.04327115 Ha
#   VQE Iteration 406: Energy = -5.05565596 Ha
#   VQE Iteration 407: Energy = -5.09438647 Ha
#   VQE Iteration 408: Energy = -5.04606829 Ha
#   VQE Iteration 409: Energy = -5.09355683 Ha
#   VQE Iteration 410: Energy = -5.10927120 Ha
#   VQE Iteration 411: Energy = -5.07500581 Ha
#   VQE Iteration 412: Energy = -5.09471441 Ha
#   VQE Iteration 413: Energy = -5.07896235 Ha
#   VQE Iteration 414: Energy = -5.07185080 Ha
#   VQE Iteration 415: Energy = -5.09668271 Ha
#   VQE Iteration 416: Energy = -5.08633202 Ha
#   VQE Iteration 417: Energy = -4.99668837 Ha
#   VQE Iteration 418: Energy = -5.06849918 Ha
#   VQE Iteration 419: Energy = -5.04289207 Ha
#   VQE Iteration 420: Energy = -5.05996493 Ha
#   VQE Iteration 421: Energy = -5.08220800 Ha
#   VQE Iteration 422: Energy = -5.05048915 Ha
#   VQE Iteration 423: Energy = -5.05511604 Ha
#   VQE Iteration 424: Energy = -5.10376085 Ha
#   VQE Iteration 425: Energy = -5.01412664 Ha
#   VQE Iteration 426: Energy = -4.99612686 Ha
#   VQE Iteration 427: Energy = -5.07185752 Ha
#   VQE Iteration 428: Energy = -5.09600616 Ha
#   VQE Iteration 429: Energy = -5.08901406 Ha
#   VQE Iteration 430: Energy = -5.08977650 Ha
#   VQE Iteration 431: Energy = -5.07168612 Ha
#   VQE Iteration 432: Energy = -5.03963793 Ha
#   VQE Iteration 433: Energy = -5.00749700 Ha
#   VQE Iteration 434: Energy = -5.09729618 Ha
#   VQE Iteration 435: Energy = -5.07290481 Ha
#   VQE Iteration 436: Energy = -5.08220966 Ha
#   VQE Iteration 437: Energy = -5.06248300 Ha
#   VQE Iteration 438: Energy = -5.03830262 Ha
#   VQE Iteration 439: Energy = -5.05360089 Ha
#   VQE Iteration 440: Energy = -5.04371539 Ha
#   VQE Iteration 441: Energy = -5.09686303 Ha
#   VQE Iteration 442: Energy = -5.08035581 Ha
#   VQE Iteration 443: Energy = -5.10090321 Ha
#   VQE Iteration 444: Energy = -5.06538593 Ha
#   VQE Iteration 445: Energy = -5.04627049 Ha
#   VQE Iteration 446: Energy = -5.05956916 Ha
#   VQE Iteration 447: Energy = -5.06135907 Ha
#   VQE Iteration 448: Energy = -5.02932168 Ha
#   VQE Iteration 449: Energy = -5.05357707 Ha
#   VQE Iteration 450: Energy = -5.11065707 Ha
#   VQE Iteration 451: Energy = -5.07065248 Ha
#   VQE Iteration 452: Energy = -5.06112963 Ha
#   VQE Iteration 453: Energy = -5.07764682 Ha
#   VQE Iteration 454: Energy = -5.07533463 Ha
#   VQE Iteration 455: Energy = -5.06371081 Ha
#   VQE Iteration 456: Energy = -5.05196290 Ha
#   VQE Iteration 457: Energy = -5.07693072 Ha
#   VQE Iteration 458: Energy = -5.05703764 Ha
#   VQE Iteration 459: Energy = -5.07443213 Ha
#   VQE Iteration 460: Energy = -5.11358163 Ha
#   VQE Iteration 461: Energy = -5.06151834 Ha
#   VQE Iteration 462: Energy = -5.06844327 Ha
#   VQE Iteration 463: Energy = -5.02626472 Ha
#   VQE Iteration 464: Energy = -5.07334102 Ha
#   VQE Iteration 465: Energy = -5.06664504 Ha
#   VQE Iteration 466: Energy = -5.06000341 Ha
#   VQE Iteration 467: Energy = -5.07061388 Ha
#   VQE Iteration 468: Energy = -5.08395832 Ha
#   VQE Iteration 469: Energy = -5.09435661 Ha
#   VQE Iteration 470: Energy = -5.13683429 Ha
#   VQE Iteration 471: Energy = -5.01630832 Ha
#   VQE Iteration 472: Energy = -5.05120930 Ha
#   VQE Iteration 473: Energy = -5.07563016 Ha
#   VQE Iteration 474: Energy = -5.10380647 Ha
#   VQE Iteration 475: Energy = -5.06733517 Ha
#   VQE Iteration 476: Energy = -5.10592190 Ha
#   VQE Iteration 477: Energy = -5.05270185 Ha
#   VQE Iteration 478: Energy = -5.08317447 Ha
#   VQE Iteration 479: Energy = -5.06539710 Ha
#   VQE Iteration 480: Energy = -5.10080160 Ha
#   VQE Iteration 481: Energy = -5.06589461 Ha
#   VQE Iteration 482: Energy = -5.10279523 Ha
#   VQE Iteration 483: Energy = -5.07801741 Ha
#   VQE Iteration 484: Energy = -5.10220470 Ha
#   VQE Iteration 485: Energy = -5.04995218 Ha
#   VQE Iteration 486: Energy = -5.10523031 Ha
#   VQE Iteration 487: Energy = -5.10926296 Ha
#   VQE Iteration 488: Energy = -5.01716186 Ha
#   VQE Iteration 489: Energy = -5.04278333 Ha
#   VQE Iteration 490: Energy = -5.07360082 Ha
#   VQE Iteration 491: Energy = -5.05642475 Ha
#   VQE Iteration 492: Energy = -5.11008098 Ha
#   VQE Iteration 493: Energy = -5.05014971 Ha
#   VQE Iteration 494: Energy = -5.09046419 Ha
#   VQE Iteration 495: Energy = -5.05872204 Ha
#   VQE Iteration 496: Energy = -5.10853475 Ha
#   VQE Iteration 497: Energy = -5.07898426 Ha
#   VQE Iteration 498: Energy = -5.09100520 Ha
#   VQE Iteration 499: Energy = -5.03867752 Ha
#   VQE Iteration 500: Energy = -5.04206275 Ha
#   VQE Iteration 501: Energy = -5.01368379 Ha
#   VQE Iteration 502: Energy = -5.06532559 Ha
#   VQE Iteration 503: Energy = -5.07005574 Ha
#   VQE Iteration 504: Energy = -5.06513959 Ha
#   VQE Iteration 505: Energy = -5.04205487 Ha
#   VQE Iteration 506: Energy = -5.08879393 Ha
#   VQE Iteration 507: Energy = -5.07135941 Ha
#   VQE Iteration 508: Energy = -5.06289483 Ha
#   VQE Iteration 509: Energy = -5.04543759 Ha
#   VQE Iteration 510: Energy = -5.06214903 Ha
#   VQE Iteration 511: Energy = -5.05357619 Ha
#   VQE Iteration 512: Energy = -5.05842528 Ha
#   VQE Iteration 513: Energy = -5.15470191 Ha
#   VQE Iteration 514: Energy = -5.07540538 Ha
#   VQE Iteration 515: Energy = -5.05560996 Ha
#   VQE Iteration 516: Energy = -5.11241163 Ha
#   VQE Iteration 517: Energy = -5.07903879 Ha
#   VQE Iteration 518: Energy = -5.07748559 Ha
#   VQE Iteration 519: Energy = -5.07297288 Ha
#   VQE Iteration 520: Energy = -5.07843097 Ha
#   VQE Iteration 521: Energy = -5.08506370 Ha
#   VQE Iteration 522: Energy = -5.10747925 Ha
#   VQE Iteration 523: Energy = -5.14018071 Ha
#   VQE Iteration 524: Energy = -5.08383320 Ha
#   VQE Iteration 525: Energy = -5.11466746 Ha
#   VQE Iteration 526: Energy = -5.09703049 Ha
#   VQE Iteration 527: Energy = -5.09154997 Ha
#   VQE Iteration 528: Energy = -5.04776825 Ha
#   VQE Iteration 529: Energy = -5.04834210 Ha
#   VQE Iteration 530: Energy = -5.05266084 Ha
#   VQE Iteration 531: Energy = -5.07148725 Ha
#   VQE Iteration 532: Energy = -5.08715068 Ha
#   VQE Iteration 533: Energy = -5.04356693 Ha
#   VQE Iteration 534: Energy = -5.07173480 Ha
#   VQE Iteration 535: Energy = -5.10006213 Ha
#   VQE Iteration 536: Energy = -5.06412858 Ha
#   VQE Iteration 537: Energy = -5.06537437 Ha
#   VQE Iteration 538: Energy = -5.04630574 Ha
#   VQE Iteration 539: Energy = -5.05338743 Ha
#   VQE Iteration 540: Energy = -5.01910975 Ha
#   VQE Iteration 541: Energy = -5.03810002 Ha
#   VQE Iteration 542: Energy = -5.08830467 Ha
#   VQE Iteration 543: Energy = -5.11653554 Ha
#   VQE Iteration 544: Energy = -5.10758878 Ha
#   VQE Iteration 545: Energy = -5.05191420 Ha
#   VQE Iteration 546: Energy = -5.04481710 Ha
#   VQE Iteration 547: Energy = -5.04220791 Ha
#   VQE Iteration 548: Energy = -5.02344075 Ha
#   VQE Iteration 549: Energy = -5.04901087 Ha
#   VQE Iteration 550: Energy = -5.06187158 Ha
#   VQE Iteration 551: Energy = -5.07016128 Ha
#   VQE Iteration 552: Energy = -5.08350595 Ha
#   VQE Iteration 553: Energy = -5.11098462 Ha
#   VQE Iteration 554: Energy = -5.10986413 Ha
#   VQE Iteration 555: Energy = -5.10143036 Ha
#   VQE Iteration 556: Energy = -5.05296285 Ha
#   VQE Iteration 557: Energy = -5.04283679 Ha
#   VQE Iteration 558: Energy = -5.04853128 Ha
#   VQE Iteration 559: Energy = -5.09300380 Ha
#   VQE Iteration 560: Energy = -5.08443532 Ha
#   VQE Iteration 561: Energy = -5.05406472 Ha
#   VQE Iteration 562: Energy = -5.09298956 Ha
#   VQE Iteration 563: Energy = -5.04452419 Ha
#   VQE Iteration 564: Energy = -5.10861190 Ha
#   VQE Iteration 565: Energy = -5.03097344 Ha
#   VQE Iteration 566: Energy = -5.10093671 Ha
#   VQE Iteration 567: Energy = -5.07544874 Ha
#   VQE Iteration 568: Energy = -5.09293864 Ha
#   VQE Iteration 569: Energy = -5.09382435 Ha
#   VQE Iteration 570: Energy = -5.05948251 Ha
#   VQE Iteration 571: Energy = -5.07373685 Ha
#   VQE Iteration 572: Energy = -5.07936694 Ha
#   VQE Iteration 573: Energy = -5.05625500 Ha
#   VQE Iteration 574: Energy = -5.07299613 Ha
#   VQE Iteration 575: Energy = -5.03901856 Ha
#   VQE Iteration 576: Energy = -5.10887291 Ha
#   VQE Iteration 577: Energy = -5.12794251 Ha
#   VQE Iteration 578: Energy = -5.03759084 Ha
#   VQE Iteration 579: Energy = -5.07352731 Ha
#   VQE Iteration 580: Energy = -5.09909255 Ha
#   VQE Iteration 581: Energy = -5.05079117 Ha
#   VQE Iteration 582: Energy = -5.04167103 Ha
#   VQE Iteration 583: Energy = -5.09887482 Ha
#   VQE Iteration 584: Energy = -5.07977876 Ha
#   VQE Iteration 585: Energy = -5.06368539 Ha
#   VQE Iteration 586: Energy = -5.09953237 Ha
#   VQE Iteration 587: Energy = -5.05530826 Ha
#   VQE Iteration 588: Energy = -5.01670370 Ha
#   VQE Iteration 589: Energy = -5.04568881 Ha
#   VQE Iteration 590: Energy = -5.05340770 Ha
#   VQE Iteration 591: Energy = -5.08534798 Ha
#   VQE Iteration 592: Energy = -5.01727917 Ha
#   VQE Iteration 593: Energy = -5.09103997 Ha
#   VQE Iteration 594: Energy = -5.05908703 Ha
#   VQE Iteration 595: Energy = -5.05145825 Ha
#   VQE Iteration 596: Energy = -5.01471645 Ha
#   VQE Iteration 597: Energy = -5.08305713 Ha
#   VQE Iteration 598: Energy = -5.08438818 Ha
#   VQE Iteration 599: Energy = -5.05362158 Ha
#   VQE Iteration 600: Energy = -5.07048962 Ha
#   VQE Iteration 601: Energy = -5.06909376 Ha
#   VQE Iteration 602: Energy = -5.06845435 Ha
#   VQE Iteration 603: Energy = -5.09694546 Ha
#   VQE Iteration 604: Energy = -5.08619930 Ha
#   VQE Iteration 605: Energy = -5.05622560 Ha
#   VQE Iteration 606: Energy = -5.10320201 Ha
#   VQE Iteration 607: Energy = -5.10685255 Ha
#   VQE Iteration 608: Energy = -5.10146023 Ha
#   VQE Iteration 609: Energy = -5.01636054 Ha
#   VQE Iteration 610: Energy = -5.05618417 Ha
#   VQE Iteration 611: Energy = -5.06681328 Ha
#   VQE Iteration 612: Energy = -5.12441758 Ha
#   VQE Iteration 613: Energy = -5.08296308 Ha
#   VQE Iteration 614: Energy = -5.04501318 Ha
#   VQE Iteration 615: Energy = -5.01811044 Ha
#   VQE Iteration 616: Energy = -5.08338013 Ha
#   VQE Iteration 617: Energy = -5.04926284 Ha
#   VQE Iteration 618: Energy = -5.07843783 Ha
#   VQE Iteration 619: Energy = -5.06067283 Ha
#   VQE Iteration 620: Energy = -5.09400333 Ha
#   VQE Iteration 621: Energy = -5.03952374 Ha
#   VQE Iteration 622: Energy = -5.08578367 Ha
#   VQE Iteration 623: Energy = -5.02311874 Ha
#   VQE Iteration 624: Energy = -5.12773783 Ha
#   VQE Iteration 625: Energy = -5.08367354 Ha
#   VQE Iteration 626: Energy = -5.05925366 Ha
#   VQE Iteration 627: Energy = -5.08071501 Ha
#   VQE Iteration 628: Energy = -5.08132324 Ha
#   VQE Iteration 629: Energy = -5.13308802 Ha
#   VQE Iteration 630: Energy = -5.11067398 Ha
#   VQE Iteration 631: Energy = -5.09876111 Ha
#   VQE Iteration 632: Energy = -5.08517745 Ha
#   VQE Iteration 633: Energy = -5.07784197 Ha
#   VQE Iteration 634: Energy = -5.05388543 Ha
#   VQE Iteration 635: Energy = -5.06363951 Ha
#   VQE Iteration 636: Energy = -5.08158622 Ha
#   VQE Iteration 637: Energy = -5.07835322 Ha
#   VQE Iteration 638: Energy = -5.05949035 Ha
#   VQE Iteration 639: Energy = -5.05837859 Ha
#   VQE Iteration 640: Energy = -5.12326343 Ha
#   VQE Iteration 641: Energy = -5.07549486 Ha
#   VQE Iteration 642: Energy = -5.05814910 Ha
#   VQE Iteration 643: Energy = -5.09631157 Ha
#   VQE Iteration 644: Energy = -5.04733846 Ha
#   VQE Iteration 645: Energy = -5.07768603 Ha
#   VQE Iteration 646: Energy = -5.08507801 Ha
#   VQE Iteration 647: Energy = -5.00321287 Ha
#   VQE Iteration 648: Energy = -5.01654264 Ha
#   VQE Iteration 649: Energy = -5.06957659 Ha
#   VQE Iteration 650: Energy = -5.03198394 Ha
#   VQE Iteration 651: Energy = -5.07329929 Ha
#   VQE Iteration 652: Energy = -5.09732035 Ha
#   VQE Iteration 653: Energy = -5.07811323 Ha
#   VQE Iteration 654: Energy = -5.03102177 Ha
#   VQE Iteration 655: Energy = -5.05508624 Ha
#   VQE Iteration 656: Energy = -5.08394257 Ha
#   VQE Iteration 657: Energy = -5.04991075 Ha
#   VQE Iteration 658: Energy = -5.06118990 Ha
#   VQE Iteration 659: Energy = -5.06440528 Ha
#   VQE Iteration 660: Energy = -5.10681419 Ha
#   VQE Iteration 661: Energy = -5.08460109 Ha
#   VQE Iteration 662: Energy = -5.07446905 Ha
#   VQE Iteration 663: Energy = -5.10090068 Ha
#   VQE Iteration 664: Energy = -5.06774664 Ha
#   VQE Iteration 665: Energy = -5.10271191 Ha
#   VQE Iteration 666: Energy = -5.11550342 Ha
#   VQE Iteration 667: Energy = -5.09068090 Ha
#   VQE Iteration 668: Energy = -5.09079623 Ha
#   VQE Iteration 669: Energy = -5.06726731 Ha
#   VQE Iteration 670: Energy = -5.09830612 Ha
#   VQE Iteration 671: Energy = -5.04759061 Ha
#   VQE Iteration 672: Energy = -5.15528965 Ha
#   VQE Iteration 673: Energy = -5.04563893 Ha
#   VQE Iteration 674: Energy = -5.07482918 Ha
#   VQE Iteration 675: Energy = -5.10483285 Ha
#   VQE Iteration 676: Energy = -5.11298156 Ha
#   VQE Iteration 677: Energy = -5.05328317 Ha
#   VQE Iteration 678: Energy = -5.07770677 Ha
#   VQE Iteration 679: Energy = -5.07508807 Ha
#   VQE Iteration 680: Energy = -5.06696019 Ha
#   VQE Iteration 681: Energy = -5.13256054 Ha
#   VQE Iteration 682: Energy = -5.06989262 Ha
#   VQE Iteration 683: Energy = -5.06496461 Ha
#   VQE Iteration 684: Energy = -5.04940042 Ha
#   VQE Iteration 685: Energy = -5.05429163 Ha
#   VQE Iteration 686: Energy = -5.06707937 Ha
#   VQE Iteration 687: Energy = -4.98185933 Ha
#   VQE Iteration 688: Energy = -5.06249524 Ha
#   VQE Iteration 689: Energy = -5.14242864 Ha
#   VQE Iteration 690: Energy = -5.04792908 Ha
#   VQE Iteration 691: Energy = -5.11646984 Ha
#   VQE Iteration 692: Energy = -5.04993895 Ha
#   VQE Iteration 693: Energy = -5.02853748 Ha
#   VQE Iteration 694: Energy = -5.10387223 Ha
#   VQE Iteration 695: Energy = -5.01533329 Ha
#   VQE Iteration 696: Energy = -5.05246808 Ha
#   VQE Iteration 697: Energy = -5.08910914 Ha
#   VQE Iteration 698: Energy = -5.07976499 Ha
#   VQE Iteration 699: Energy = -5.04917045 Ha
#   VQE Iteration 700: Energy = -5.07052609 Ha
#   VQE Iteration 701: Energy = -5.06461931 Ha
#   VQE Iteration 702: Energy = -5.08304527 Ha
#   VQE Iteration 703: Energy = -5.08876699 Ha
#   VQE Iteration 704: Energy = -5.06190891 Ha
#   VQE Iteration 705: Energy = -5.08096042 Ha
#   VQE Iteration 706: Energy = -5.10278818 Ha
#   VQE Iteration 707: Energy = -5.04620049 Ha
#   VQE Iteration 708: Energy = -5.08059833 Ha
#   VQE Iteration 709: Energy = -5.07871350 Ha
#   VQE Iteration 710: Energy = -5.05105766 Ha
#   VQE Iteration 711: Energy = -5.06910807 Ha
#   VQE Iteration 712: Energy = -5.08312721 Ha
#   VQE Iteration 713: Energy = -5.06548854 Ha
#   VQE Iteration 714: Energy = -5.08236629 Ha
#   VQE Iteration 715: Energy = -5.12258674 Ha
#   VQE Iteration 716: Energy = -5.07700577 Ha
#   VQE Iteration 717: Energy = -5.06716548 Ha
#   VQE Iteration 718: Energy = -5.07559518 Ha
#   VQE Iteration 719: Energy = -5.06378858 Ha
#   VQE Iteration 720: Energy = -5.02440752 Ha
#   VQE Iteration 721: Energy = -5.07790521 Ha
#   VQE Iteration 722: Energy = -5.03745500 Ha
#   VQE Iteration 723: Energy = -5.01837254 Ha
#   VQE Iteration 724: Energy = -5.10652711 Ha
#   VQE Iteration 725: Energy = -5.08696340 Ha
#   VQE Iteration 726: Energy = -5.03191246 Ha
#   VQE Iteration 727: Energy = -5.06773136 Ha
#   VQE Iteration 728: Energy = -5.09297302 Ha
#   VQE Iteration 729: Energy = -5.05993739 Ha
#   VQE Iteration 730: Energy = -5.02736195 Ha
#   VQE Iteration 731: Energy = -5.05667138 Ha
#   VQE Iteration 732: Energy = -5.09603191 Ha
#   VQE Iteration 733: Energy = -5.04780640 Ha
#   VQE Iteration 734: Energy = -5.08550654 Ha
#   VQE Iteration 735: Energy = -5.03225935 Ha
#   VQE Iteration 736: Energy = -5.10738195 Ha
#   VQE Iteration 737: Energy = -5.10792444 Ha
#   VQE Iteration 738: Energy = -5.08596247 Ha
#   VQE Iteration 739: Energy = -5.06469842 Ha
#   VQE Iteration 740: Energy = -5.04316147 Ha
#   VQE Iteration 741: Energy = -5.04567012 Ha
#   VQE Iteration 742: Energy = -5.09562993 Ha
#   VQE Iteration 743: Energy = -5.05806533 Ha
#   VQE Iteration 744: Energy = -5.05705147 Ha
#   VQE Iteration 745: Energy = -5.08051256 Ha
#   VQE Iteration 746: Energy = -5.07189942 Ha
#   VQE Iteration 747: Energy = -5.13014057 Ha
#   VQE Iteration 748: Energy = -5.11136197 Ha
#   VQE Iteration 749: Energy = -5.05959717 Ha
#   VQE Iteration 750: Energy = -5.10702635 Ha
#   VQE Iteration 751: Energy = -5.08943376 Ha
#   VQE Iteration 752: Energy = -5.11230841 Ha
#   VQE Iteration 753: Energy = -5.09250562 Ha
#   VQE Iteration 754: Energy = -5.00594346 Ha
#   VQE Iteration 755: Energy = -5.04170717 Ha
#   VQE Iteration 756: Energy = -5.04267518 Ha
# VQE calculation finished in 1182.58s
#
#
# ==================================================
#            Final Energy Summary
# ==================================================
#   UHF Energy:         -75.98397342 Hartree
#   VQE Energy:         -74.81705323 Hartree
#   FCI (Exact) Energy: -76.12087584 Hartree
# --------------------------------------------------
#   Error (VQE vs FCI): 1.30382261 Hartree
# ==================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 140
#     137     plt.show()
#     139 if __name__ == "__main__":
# --> 140     main()
#
# Cell In[1], line 130, in main()
#     128 plt.axhline(y=results['FCI'], color='r', linestyle='--', label='FCI (Exact) Energy')
#     129 # This is the exact energy within the active space, which VQE should approach
# --> 130 exact_active_space_energy = problem.interpret(vqe_calc_result).ground_energy + problem.reference_energy
#     131 plt.axhline(y=exact_active_space_energy, color='g', linestyle='--', label='Exact Active Space Energy')
#     132 plt.title('VQE Convergence for H₂O')
#
# AttributeError: 'ElectronicStructureResult' object has no attribute 'ground_energy'
